# %%
import pandas as pd

# %%
df = pd.read_csv('HousingData.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
"checking for any NA values!!"
# Out:
# 'checking for any NA values!!'

# %%
df.isna().any()
# Out:
# CRIM        True
# ZN          True
# INDUS       True
# CHAS        True
# NOX        False
# RM         False
# AGE         True
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT       True
# MEDV       False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df1 = df.dropna()
df1.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df1.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 5  394.12   5.21  28.7

# %%
x = df1.drop(['MEDV'],axis='columns')
y = df1['MEDV']

# %%
"training the dataset!"
# Out:
# 'training the dataset!'

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=30)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.7524343714963592

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([28.73106154, 10.21511634, 30.52633077,  5.40839448, 21.77599728,
#        35.30447552, 18.5111559 , 39.24033519, 14.70878068, 17.06487628,
#        29.78637249, 22.07939262, 22.34551091, 32.77116244, 23.56259273,
#        28.88692567, 21.42101516, 24.98125331,  3.74403731, 25.23124763,
#        20.37026775, 24.65473524, 25.97810607, 22.23261752, 40.72846913,
#         9.19378445, 30.88854762, 17.79974656, 25.26606202, 13.43101099,
#        28.75590562, 38.60660861, 27.30259811, 31.77184312, 24.09020288,
#        25.46885662, 24.96212478, 20.12743785, 43.04289621, 40.04458786,
#        34.63947001,  7.74714706, 20.22366242, 25.0910808 , 33.39598804,
#        27.43967485, 19.63876161, 27.05740706, 19.57058165, 15.24492405,
#        21.54780377, -0.06701731, 16.2624323 , 29.18238032, 19.84695347,
#        32.29063829, 23.14551924, 27.85523792, 30.60924729, 20.18521172,
#        14.94917566, 16.83364726, 17.0324318 , 20.13252192, 18.861321  ,
#        45.9667946 , 18.17235211, 19.85076528, 17.09394401, 16.62220374,
#        17.79371661, 12.49926758, 16.74304912, 22.71199198, 10.41122685,
#         6.36312242, 22.59412597, 28.42453302, 25.09815838])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
mse
# Out:
# 21.14426497290157

# %%
mae
# Out:
# 3.4278148254271525

# %%
r2
# Out:
# 0.7524343714963592
